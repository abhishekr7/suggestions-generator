# %% [markdown]
# # Import necessary libraries

# %%
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Business dataset

# %%
article_path = '/home/abhishek/Documents/NLP/Blog/suggestions-generator/bbc-news-summary/articles/sport/'
summary_path = '/home/abhishek/Documents/NLP/Blog/suggestions-generator/bbc-news-summary/summaries/sport/'
n_examples = 511

# %% [markdown]
# # Create a word list for both articles and summaries

# %%
Tokenizer = RegexpTokenizer(r'[A-Za-z0-9\$]+')
article_word_list = []
summary_word_list = []

for i in range(1,n_examples+1):
    
    # ARTICLE
    
    with open(article_path+'{:03}.txt'.format(i),'r') as article_file:
        text = article_file.read()
        word_list = [word.lower() for word in Tokenizer.tokenize(text)]
        article_word_list.extend(word_list)
        
    # SUMMARY
    
    with open(summary_path+'{:03}.txt'.format(i),'r') as summary_file:
        text = summary_file.read()
        word_list = [word.lower() for word in Tokenizer.tokenize(text)]
        summary_word_list.extend(word_list)

# %% [markdown]
# # Create a word set for both articles and summaries

# %%
article_word_set = set(article_word_list)
summary_word_set = set(summary_word_list)

# %% [markdown]
# # Create a common word set

# %%
all_word_set = set().union(article_word_set).union(summary_word_set)

# %%
len(all_word_set)
# Out:
# 10614

# %% [markdown]
# # number of times "only" used in article

# %%
def when_in_article_only(WORD):
    
    internal_count = 0
    count = 0
    
    for i in range(1,n_examples+1):
        
        in_article = False
        in_summary = False
        
        # ARTICLE
        
        with open(article_path+'{:03}.txt'.format(i),'r') as article_file:
            text = article_file.read()
            
            word_list = [word.lower() for word in Tokenizer.tokenize(text)]
            
            if WORD in word_list:
                in_article = True
    
                for x in word_list:
                    if x == WORD:
                        internal_count += 1
                    
        
        # SUMMARY
        
        with open(summary_path+'{:03}.txt'.format(i),'r') as summary_file:
            text = summary_file.read()
            
            word_list = [word.lower() for word in Tokenizer.tokenize(text)]
            
            if WORD in word_list:
                in_summary = True
        
        if in_article == True and in_summary == False:
            count += internal_count
        
    return count

# %% [markdown]
# # number of times "only" used in summary

# %%
def when_in_summary_only(WORD):
    
    internal_count = 0
    count = 0
    
    for i in range(1,n_examples+1):
        
        in_article = False
        in_summary = False
        
        # ARTICLE
        
        with open(article_path+'{:03}.txt'.format(i),'r') as article_file:
            text = article_file.read()
            
            word_list = [word.lower() for word in Tokenizer.tokenize(text)]
            
            if WORD in word_list:
                in_article = True
                    
        
        # SUMMARY
        
        with open(summary_path+'{:03}.txt'.format(i),'r') as summary_file:
            text = summary_file.read()
            
            word_list = [word.lower() for word in Tokenizer.tokenize(text)]
            
            if WORD in word_list:
                in_summary = True
                
                for x in word_list:
                    if x == WORD:
                        internal_count += 1
        
        if in_article == True and in_summary == False:
            count += internal_count
        
    return count

# %% [markdown]
# # number of times used in both

# %%
def when_in_both(WORD):
    
    internal_count_article = 0
    internal_count_summary = 0
    
    count = 0
    
    for i in range(1,n_examples+1):
        
        in_article = False
        in_summary = False
        
        # ARTICLE
        
        with open(article_path+'{:03}.txt'.format(i),'r') as article_file:
            text = article_file.read()
            
            word_list = [word.lower() for word in Tokenizer.tokenize(text)]
            
            if WORD in word_list:
                in_article = True
                
                for x in word_list:
                    if x == WORD:
                        internal_count_article += 1
        
        # SUMMARY
        
        with open(summary_path+'{:03}.txt'.format(i),'r') as summary_file:
            text = summary_file.read()
            
            word_list = [word.lower() for word in Tokenizer.tokenize(text)]
            
            if WORD in word_list:
                in_summary = True
                
                for x in word_list:
                    if x == WORD:
                        internal_count_summary += 1
        
        if in_article == True and in_summary == True:
            count += min(internal_count_article,internal_count_summary)
        
    return count

# %% [markdown]
# # total number of times used

# %%
def total_usage(word):
    count = 0
    
    for item in article_word_list:
        if item == word:
            count += 1
    
    for item in summary_word_list:
        if item == word:
            count += 1
    
    return count

# %% [markdown]
# # create a dataframe with all usage counts

# %%
df = pd.DataFrame(columns=['word','#article','#summary','#both','#total'])
df.set_index(['word'])

cnt = 0

for item in all_word_set:
    cnt += 1
    w = when_in_article_only(item)
    x = when_in_summary_only(item)
    y = when_in_both(item)
    z = total_usage(item)
    df.loc[item] = [item,w,x,y,z]
    print(cnt)

# %% [markdown]
# # display dataframe

# %%
df['R_article'] = df['#article']/df['#total']

# %%
df['R_summary'] = df['#summary']/df['#total']

# %%
df['R_both'] = df['#both']/df['#total']

# %%
df
# Out:
#                   word #article #summary #both #total R_article R_summary  \
# raining        raining        2        0     0      2         1         0
# both              both        0        0    44    179         0         0
# foul              foul        0        0     3     10         0         0
# four              four        0        0    60    232         0         0
# hanging        hanging        0        0     1      6         0         0
# plaudits      plaudits        1        0     0      1         1         0
# francesca    francesca        0        0     1      3         0         0
# cyprus          cyprus        0        0     1     20         0         0
# aggression  aggression        0        0     1      2         0         0
# sevens          sevens        0        0     5     26         0         0
# increase      increase        0        0     1      4         0         0
# eligible      eligible        2        0     0      2         1         0
# crossbar      crossbar        1        0     0      1         1         0
# hermann        hermann        0        0     1      2         0         0
# lord              lord        0        0     3      6         0         0
# ioannidis    ioannidis        0        0     3     13         0         0
# meadows        meadows        0        0     1      3         0         0
# dwyer            dwyer        1        0     0      1         1         0
# heintze        heintze        1        0     0      1         1         0
# figo              figo        2        0     0      2         1         0
# regional      regional        0        0     2     10         0         0
# stipulate    stipulate        1        0     0      1         1         0
# replaces      replaces        0        0     4     10         0         0
# leisurely    leisurely        1        0     0      1         1         0
# bringing      bringing        0        0     5     19         0         0
# bromby          bromby        0        0     1      2         0         0
# prize            prize        0        0     6     32         0         0
# nottingham  nottingham        0        0     2     11         0         0
# wooden          wooden        0        0     5     14         0         0
# wednesday    wednesday        0        0    26     96         0         0
# ...                ...      ...      ...   ...    ...       ...       ...
# mido              mido        0        0     2     19         0         0
# conspired    conspired        1        0     0      1         1         0
# kanu              kanu        1        0     0      1         1         0
# improving    improving        0        0     3      9         0         0
# saretta        saretta        0        0     1      2         0         0
# boot              boot        0        0     3     13         0         0
# abigail        abigail        0        0     1      2         0         0
# debutant      debutant        0        0     2      8         0         0
# poms              poms        0        0     1      2         0         0
# other            other        0        0    47    178         0         0
# toured          toured        0        0     2      6         0         0
# incredibly  incredibly        0        0     1      2         0         0
# withstood    withstood        0        0     1      3         0         0
# illegally    illegally        0        0     2      4         0         0
# quashie        quashie        0        0     1      7         0         0
# kinds            kinds        0        0     1      2         0         0
# dallaglio    dallaglio        0        0     9     69         0         0
# lively          lively        0        0     2      7         0         0
# hardenne      hardenne        0        0     5     21         0         0
# enqvist        enqvist        4        0     0      4         1         0
# june              june        0        0     8     41         0         0
# 100m              100m        0        0    14     49         0         0
# frustrate    frustrate        0        0     1      2         0         0
# risked          risked        0        0     1      2         0         0
# margaret      margaret        0        0     1      2         0         0
# pumps            pumps        1        0     0      1         1         0
# priced          priced        0        0     1      2         0         0
# ranks            ranks        0        0     1      4         0         0
# volumes        volumes        2        0     0      2         1         0
# richardson  richardson        0        0     1      3         0         0
#
#               R_both
# raining            0
# both         0.24581
# foul             0.3
# four        0.258621
# hanging     0.166667
# plaudits           0
# francesca   0.333333
# cyprus          0.05
# aggression       0.5
# sevens      0.192308
# increase        0.25
# eligible           0
# crossbar           0
# hermann          0.5
# lord             0.5
# ioannidis   0.230769
# meadows     0.333333
# dwyer              0
# heintze            0
# figo               0
# regional         0.2
# stipulate          0
# replaces         0.4
# leisurely          0
# bringing    0.263158
# bromby           0.5
# prize         0.1875
# nottingham  0.181818
# wooden      0.357143
# wednesday   0.270833
# ...              ...
# mido        0.105263
# conspired          0
# kanu               0
# improving   0.333333
# saretta          0.5
# boot        0.230769
# abigail          0.5
# debutant        0.25
# poms             0.5
# other       0.264045
# toured      0.333333
# incredibly       0.5
# withstood   0.333333
# illegally        0.5
# quashie     0.142857
# kinds            0.5
# dallaglio   0.130435
# lively      0.285714
# hardenne    0.238095
# enqvist            0
# june        0.195122
# 100m        0.285714
# frustrate        0.5
# risked           0.5
# margaret         0.5
# pumps              0
# priced           0.5
# ranks           0.25
# volumes            0
# richardson  0.333333
#
# [10614 rows x 8 columns]

# %%
df['x_not'] = df['R_both'] - df['R_article']

# %%
df['y_not'] = df['R_both'] - df['R_summary']

# %%
df
# Out:
#                   word #article #summary #both #total R_article R_summary  \
# raining        raining        2        0     0      2         1         0
# both              both        0        0    44    179         0         0
# foul              foul        0        0     3     10         0         0
# four              four        0        0    60    232         0         0
# hanging        hanging        0        0     1      6         0         0
# plaudits      plaudits        1        0     0      1         1         0
# francesca    francesca        0        0     1      3         0         0
# cyprus          cyprus        0        0     1     20         0         0
# aggression  aggression        0        0     1      2         0         0
# sevens          sevens        0        0     5     26         0         0
# increase      increase        0        0     1      4         0         0
# eligible      eligible        2        0     0      2         1         0
# crossbar      crossbar        1        0     0      1         1         0
# hermann        hermann        0        0     1      2         0         0
# lord              lord        0        0     3      6         0         0
# ioannidis    ioannidis        0        0     3     13         0         0
# meadows        meadows        0        0     1      3         0         0
# dwyer            dwyer        1        0     0      1         1         0
# heintze        heintze        1        0     0      1         1         0
# figo              figo        2        0     0      2         1         0
# regional      regional        0        0     2     10         0         0
# stipulate    stipulate        1        0     0      1         1         0
# replaces      replaces        0        0     4     10         0         0
# leisurely    leisurely        1        0     0      1         1         0
# bringing      bringing        0        0     5     19         0         0
# bromby          bromby        0        0     1      2         0         0
# prize            prize        0        0     6     32         0         0
# nottingham  nottingham        0        0     2     11         0         0
# wooden          wooden        0        0     5     14         0         0
# wednesday    wednesday        0        0    26     96         0         0
# ...                ...      ...      ...   ...    ...       ...       ...
# mido              mido        0        0     2     19         0         0
# conspired    conspired        1        0     0      1         1         0
# kanu              kanu        1        0     0      1         1         0
# improving    improving        0        0     3      9         0         0
# saretta        saretta        0        0     1      2         0         0
# boot              boot        0        0     3     13         0         0
# abigail        abigail        0        0     1      2         0         0
# debutant      debutant        0        0     2      8         0         0
# poms              poms        0        0     1      2         0         0
# other            other        0        0    47    178         0         0
# toured          toured        0        0     2      6         0         0
# incredibly  incredibly        0        0     1      2         0         0
# withstood    withstood        0        0     1      3         0         0
# illegally    illegally        0        0     2      4         0         0
# quashie        quashie        0        0     1      7         0         0
# kinds            kinds        0        0     1      2         0         0
# dallaglio    dallaglio        0        0     9     69         0         0
# lively          lively        0        0     2      7         0         0
# hardenne      hardenne        0        0     5     21         0         0
# enqvist        enqvist        4        0     0      4         1         0
# june              june        0        0     8     41         0         0
# 100m              100m        0        0    14     49         0         0
# frustrate    frustrate        0        0     1      2         0         0
# risked          risked        0        0     1      2         0         0
# margaret      margaret        0        0     1      2         0         0
# pumps            pumps        1        0     0      1         1         0
# priced          priced        0        0     1      2         0         0
# ranks            ranks        0        0     1      4         0         0
# volumes        volumes        2        0     0      2         1         0
# richardson  richardson        0        0     1      3         0         0
#
#               R_both     x_not     y_not
# raining            0        -1         0
# both         0.24581   0.24581   0.24581
# foul             0.3       0.3       0.3
# four        0.258621  0.258621  0.258621
# hanging     0.166667  0.166667  0.166667
# plaudits           0        -1         0
# francesca   0.333333  0.333333  0.333333
# cyprus          0.05      0.05      0.05
# aggression       0.5       0.5       0.5
# sevens      0.192308  0.192308  0.192308
# increase        0.25      0.25      0.25
# eligible           0        -1         0
# crossbar           0        -1         0
# hermann          0.5       0.5       0.5
# lord             0.5       0.5       0.5
# ioannidis   0.230769  0.230769  0.230769
# meadows     0.333333  0.333333  0.333333
# dwyer              0        -1         0
# heintze            0        -1         0
# figo               0        -1         0
# regional         0.2       0.2       0.2
# stipulate          0        -1         0
# replaces         0.4       0.4       0.4
# leisurely          0        -1         0
# bringing    0.263158  0.263158  0.263158
# bromby           0.5       0.5       0.5
# prize         0.1875    0.1875    0.1875
# nottingham  0.181818  0.181818  0.181818
# wooden      0.357143  0.357143  0.357143
# wednesday   0.270833  0.270833  0.270833
# ...              ...       ...       ...
# mido        0.105263  0.105263  0.105263
# conspired          0        -1         0
# kanu               0        -1         0
# improving   0.333333  0.333333  0.333333
# saretta          0.5       0.5       0.5
# boot        0.230769  0.230769  0.230769
# abigail          0.5       0.5       0.5
# debutant        0.25      0.25      0.25
# poms             0.5       0.5       0.5
# other       0.264045  0.264045  0.264045
# toured      0.333333  0.333333  0.333333
# incredibly       0.5       0.5       0.5
# withstood   0.333333  0.333333  0.333333
# illegally        0.5       0.5       0.5
# quashie     0.142857  0.142857  0.142857
# kinds            0.5       0.5       0.5
# dallaglio   0.130435  0.130435  0.130435
# lively      0.285714  0.285714  0.285714
# hardenne    0.238095  0.238095  0.238095
# enqvist            0        -1         0
# june        0.195122  0.195122  0.195122
# 100m        0.285714  0.285714  0.285714
# frustrate        0.5       0.5       0.5
# risked           0.5       0.5       0.5
# margaret         0.5       0.5       0.5
# pumps              0        -1         0
# priced           0.5       0.5       0.5
# ranks           0.25      0.25      0.25
# volumes            0        -1         0
# richardson  0.333333  0.333333  0.333333
#
# [10614 rows x 10 columns]

# %%
stop_words = set(stopwords.words('english'))

word_label = df['word'].tolist()
x_coord = df['x_not'].tolist()
y_coord = df['y_not'].tolist()

area = np.pi*0.1

plotted = set()

for i,label in enumerate(word_label):
    #print(i)
    
    if label in stop_words:
        continue
    
    temp_x = x_coord[i]
    temp_y = y_coord[i]
    
    #print(str(temp_x) + " " + str(temp_y))
    
    x = abs((temp_x - temp_y - 1)/np.sqrt(2))
    y = abs((temp_x + temp_y + 1)/np.sqrt(2))
    
    #print(x)
    
    if (x,y) not in plotted:
        plt.scatter(x,y, s=area, color = 'red')
        x_label = x + 0.005
        y_label = y + 0.005
        
        if y_label > 1.4:
            plt.text(x_label, y_label, label, fontsize=9)
        plotted.add((x,y))
    #print(label)
plt.show()

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-00cf07b74dcd> in <module>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# # calculate the salience Threshold Q

# %%
Q = df[df['#both'] >= 10]['y_not'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9dc1b022b57a> in <module>()
# ----> 1 Q = df[df['#both'] >= 10]['y_not'].mean()
#
# NameError: name 'df' is not defined

# %%
with open('/home/abhishek/Documents/NLP/Blog/test_article.txt') as test_article:
    text1 = test_article.read()

# %%
text1
# Out:
# 'Virgil van Dijk and Vivianne Miedema win PFA Player of the Year awards\nDutch duo Virgil van Dijk and Vivianne Miedema have won the Professional Footballers\' Association Player of the Year awards for 2018-19.\nLiverpool defender Van Dijk, 27, beat Raheem Sterling, Bernardo Silva, Sergio Aguero, Sadio Mane and Eden Hazard in the vote by his fellow players.\nArsenal forward Miedema, 22, beat Steph Houghton, Nikita Parris, Keira Walsh, Erin Cuthbert and Ji So-yun.\nManchester City forward Sterling won the men\'s Young Player of the Year.\nCity also provided winners for two other awards, with England forward Georgia Stanway claiming the women\'s young player prize and England captain Houghton receiving the PFA Special Achievement award.\nVan Dijk succeeds Liverpool team-mate Mohamed Salah, who won in 2017-18, and is the first defender to take the award since Chelsea centre-back John Terry in 2004-05.\nMiedema, who helped Arsenal clinch their first Women\'s Super League title since 2012 earlier on Sunday, follows Chelsea and England striker Fran Kirby.\nVan Dijk has been one of the key players in Liverpool\'s ongoing title challenge this season, playing in every one of their Premier League fixtures.\nSigned in January 2018 from Southampton for a world record fee for a defender of \xc2\xa375m, the Netherlands international has been a rock at the heart of the Reds\' defence.\nLiverpool have kept 19 clean sheets from their 36 league games this season, 28 of which they have won.\nHe has also contributed three goals and two assists during the campaign.\n"It\'s the highest honour you can get as a player to get voted player of the year by the players you play against every week," said Van Dijk.\n"It\'s special. I\'m very proud and honoured to receive it."\nVan Dijk could still end the season with a Premier League winner\'s medal with Liverpool trailing Manchester City by a single point with two matches remaining.\nChelsea playmaker Hazard, who won in 2014-15, was nominated alongside the City trio of Aguero, Silva and Sterling, and Van Dijk\'s Liverpool team-mate Mane.\nNetherlands international Miedema is the top scorer in the WSL this season, netting 22 goals and providing 10 assists in her 19 appearances.\nIn all competitions this season, the prolific striker has scored 39 goals in 46 appearances.\nThe former Bayern Munich player hit the opener as Arsenal secured the WSL title with a 4-0 win at Brighton\'s Amex Stadium, in front of a new league-record crowd.\n"I\'m obviously really proud to represent my team here, we\'ve had an amazing year, especially with winning the league," she said.'

# %%
with open('/home/abhishek/Documents/NLP/Blog/test_summary.txt') as test_summary:
    text2 = test_summary.read()

# %%
text2
# Out:
# "Virgil van Dijk and Vivianne Miedema win PFA Player of the Year awards\n\nDutch duo Virgil van Dijk and Vivianne Miedema have won the Professional Footballers' Association Player of the Year awards for 2018-19. Liverpool defender Van Dijk, 27, beat Raheem Sterling, Bernardo Silva, Sergio Aguero, Sadio Mane and Eden Hazard in the vote by his fellow players. Van Dijk succeeds Liverpool team-mate Mohamed Salah, who won in 2017-18, and is the first defender to take the award since Chelsea centre-back John Terry in 2004-05. Miedema, who helped Arsenal clinch their first Women's Super League title since 2012 earlier on Sunday, follows Chelsea and England striker Fran Kirby. \n\nVan Dijk has been one of the key players in Liverpool's ongoing title challenge this season, playing in every one of their Premier League fixtures. Liverpool have kept 19 clean sheets from their 36 league games this season, 28 of which they have won. He has also contributed three goals and two assists during the campaign. \xc2\xabIt's the highest honour you can get as a player to get voted player of the year by the players you play against every week,\xc2\xbb said Van Dijk. \n\nChelsea playmaker Hazard, who won in 2014-15, was nominated alongside the City trio of Aguero, Silva and Sterling, and Van Dijk's Liverpool team-mate Mane. Netherlands international Miedema is the top scorer in the WSL this season, netting 22 goals and providing 10 assists in her 19 appearances. In all competitions this season, the prolific striker has scored 39 goals in 46 appearances. The former Bayern Munich player hit the opener as Arsenal secured the WSL title with a 4-0 win at Brighton's Amex Stadium, in front of a new league-record crowd. "

# %%
article_Set = set(Tokenizer.tokenize(text1))

# %%
summary_Set = set(Tokenizer.tokenize(text2))

# %%
remain_Set = set()

# %%
for x in article_Set:
    if x not in summary_Set:
        remain_Set.add(x)

# %%
suggestions = set()

for item in remain_Set:
    try:
        if df.loc[item]['y_not'] > Q:
            for item_s in summary_Set:
                if df.loc[item]['y_not'] > df.loc[item_s]['y_not']:
                    suggestions.add(item)
                    break   
    except:
        continue
